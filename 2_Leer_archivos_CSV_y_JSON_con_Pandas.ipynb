# %% [markdown]
# <a href="https://colab.research.google.com/github/Yesenia-AriasC/Introduccion-Pandas-Python/blob/main/2_Leer_archivos_CSV_y_JSON_con_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Leer archivos CSV | pd.read_csv() 🐼
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#
# Es muy parecido a Deepnote, solamente que allí debemos subir el archivo a usar directamente en el proyecto; de resto es igual.

# %% [markdown]
# ## En colaboratory

# %% [markdown]
# 1. Guardamos el archivo también en la cuenta drive en que estamos usando colab, en mi ejemplo, voy a guardarlo en la misma carpeta en que tengo este notebook bajo el nombre de "archivo.csv".
# 2.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/Yesenia-AriasC/Introduccion-Pandas-Python/main/Imagenes/activar.png" width="280" >

# %% [markdown]
# <img src="https://raw.githubusercontent.com/Yesenia-AriasC/Introduccion-Pandas-Python/main/Imagenes/permitir.png" width="600" >

# %% [markdown]
# 3. Luego de conectar con la cuenta, copiamos la ruta de acceso del archivo de la siguiente manera:

# %% [markdown]
# <img src="https://raw.githubusercontent.com/Yesenia-AriasC/Introduccion-Pandas-Python/main/Imagenes/ruta.png" width="380" >

# %% [markdown]
# 4. Usamos la libreriá pandas para abrirlo usando la dirección de acceso que copiamos anteriormente.

# %% [markdown]
# ## Abriendo el archivo

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv')
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ### df.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %% [markdown]
# # Cuando el separador no es una coma "," | Atributo sep

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv', sep=",")
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# # Cuando los títulos de las variables están mal | Atributo header

# %% [markdown]
# Hay veces en que nuestro dataframe luce así:

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv', header=1)
# Out:
#                          10-Day Green Smoothie Cleanse  \
# 0                                    11/22/63: A Novel
# 1              12 Rules for Life: An Antidote to Chaos
# 2                               1984 (Signet Classics)
# 3    5,000 Awesome Facts (About Everything!) (Natio...
# 4        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 544       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 545  You Are a Badass: How to Stop Doubting Your Gr...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
#
#                      JJ Smith  4.7  17350   8  2016  Non Fiction
# 0                Stephen King  4.6   2052  22  2011      Fiction
# 1          Jordan B. Peterson  4.7  18979  15  2018  Non Fiction
# 2               George Orwell  4.7  21424   6  2017      Fiction
# ...

# %% [markdown]
# Esto se soluciona con ````header````, vemos que en nuestro caso específico, los títulos de mi variable se encuentran el la posición 0, por lo que podemos colocar header=0 (**es su valor por defecto**)

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv', header=0)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## header = None
#
# En caso de que las columns o variables no tengan nombres

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv', header=None)
# Out:
#                                                      0                   1  \
# 0                                                 Name              Author
# 1                        10-Day Green Smoothie Cleanse            JJ Smith
# 2                                    11/22/63: A Novel        Stephen King
# 3              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 546       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 547  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 550  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#                2        3      4     5            6
# ...

# %% [markdown]
# # Cambiando nombres de columnas o variables | Atributo names
#
# __Importante!__ colocar el header si tiene, si no, no es necesario usar el atributo header, solo manes.

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv',header=0, names= ['Namesss', 'Authhhhhor', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])
# Out:
#                                                Namesss  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                    Authhhhhor  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# ## Ten en cuenta colocar header cuando las columnas tinen nombre

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/PYTHON CIENCIA DE DATOS/Pandas/archivo.csv', names= ['Namesss', 'Authhhhhor', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'])
# Out:
#                                                Namesss          Authhhhhor  \
# 0                                                 Name              Author
# 1                        10-Day Green Smoothie Cleanse            JJ Smith
# 2                                    11/22/63: A Novel        Stephen King
# 3              12 Rules for Life: An Antidote to Chaos  Jordan B. Peterson
# 4                               1984 (Signet Classics)       George Orwell
# ..                                                 ...                 ...
# 546       Wrecking Ball (Diary of a Wimpy Kid Book 14)         Jeff Kinney
# 547  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
# 550  You Are a Badass: How to Stop Doubting Your Gr...         Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# # Leer archivos JSON | pd.read_json() 🐼
#
# [Documentación](https://pandas.pydata.org/docs/reference/api/pandas.read_json.html)
#
# Es exactamente lo mismo, solo que se usa  pd.read_csv()

# %% [markdown]
# # Leer tablas de INTERNET |  pd.read_html('link') 🐼
#
# El objeto resultante es una lista de dataframes, los que representan cada una de las tablas de la página.

# %% [markdown]
# ## Ejemplo 1
#
# Vamos a obtener la lista de tablas (DataFrame) de la página de wikipedia de __"Clasificación de Conmebol para la Copa Mundial de Fútbol de 2022"__
#
# https://es.wikipedia.org/wiki/Clasificaci%C3%B3n_de_Conmebol_para_la_Copa_Mundial_de_F%C3%BAtbol_de_2022

# %%
todas = pd.read_html('https://es.wikipedia.org/wiki/Clasificaci%C3%B3n_de_Conmebol_para_la_Copa_Mundial_de_F%C3%BAtbol_de_2022')

# %%
# El objeto guardado en "todas" es una lista
print(type(todas))
# Out:
# <class 'list'>

# %% [markdown]
#  el primer elemento guardado en esa lista es un Dataframe

# %%
print(type(todas[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
todas[0]
# Out:
#    VII Clasificación de Conmebol para la Copa Mundial de FútbolConmebol 2020-2022  \
# 0   Brasil cerró la eliminatoria en el primer pues...
# 1                                     Datos generales
# 2                                                Sede
# 3                                     Fecha de inicio
# 4                                     Fecha de cierre
# 5                                             Edición
# 6                                         Organizador
# 7                                            Palmarés
# 8                                        Clasificados
# 9                                  Datos estadísticos
# 10                                      Participantes
# 11                                           Partidos
# 12                                              Goles
# 13                                           Goleador
# 14                                                NaN
# 15                                         Cronología
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ___

# %%
todas[2]
# Out:
#    Selección                  Entrenador  \
# 0  Argentina              Lionel Scaloni
# 1    Bolivia                César Farías
# 2     Brasil                        Tite
# 3      Chile              Martín Lasarte
# 4   Colombia              Reinaldo Rueda
# 5    Ecuador              Gustavo Alfaro
# 6   Paraguay  Guillermo Barros Schelotto
# 7       Perú              Ricardo Gareca
# 8    Uruguay                Diego Alonso
# 9  Venezuela        José Néstor Pékerman
#
#                                       Ciudad localía  \
# 0     Buenos AiresCórdobaSantiago del EsteroSan Juan
# 1                                             La Paz
# 2  Río de JaneiroSão PauloSalvador de BahíaPorto ...
# 3                                     SantiagoCalama
# 4                                       Barranquilla
# 5                                     QuitoGuayaquil
# 6                            AsunciónCiudad del Este
# 7                                               Lima
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ___

# %%
todas[3]
# Out:
#    Selección       Entrenador saliente               Fecha de salida  \
# 0    Ecuador              Jordi Cruyff       23 de julio de 2020[7]​
# 1   Colombia            Carlos Queiroz    1 de diciembre de 2020[8]​
# 2      Chile            Reinaldo Rueda   31 de diciembre de 2020[9]​
# 3  Venezuela              José Peseiro     20 de agosto de 2021[10]​
# 4   Paraguay           Eduardo Berizzo    14 de octubre de 2021[11]​
# 5  Venezuela         Leonardo González  19 de noviembre de 2021[13]​
# 6    Uruguay  Óscar Washington Tabárez  19 de noviembre de 2021[15]​
#
#          Tipo de salida    Partidos disputados             Reemplazado por  \
# 0              Renuncia   0 (0 PG, 0 PE, 0 PP)              Gustavo Alfaro
# 1               Despido   4 (1 PG, 1 PE, 2 PP)              Reinaldo Rueda
# 2  Fichado por Colombia   4 (1 PG, 1 PE, 2 PP)              Martín Lasarte
# 3              Renuncia   6 (1 PG, 1 PE, 4 PP)           Leonardo González
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
todas[4]
# Out:
#                                                     0  \
# 0   Partidos de ida Jornada Fecha Jornada 1 8 y 9 ...
# 1                                     Partidos de ida
# 2                                             Jornada
# 3                                           Jornada 1
# 4                                           Jornada 2
# 5                                           Jornada 3
# 6                                           Jornada 4
# 7                                           Jornada 5
# 8                                           Jornada 6
# 9                                           Jornada 7
# 10                                          Jornada 8
# 11                                          Jornada 9
# 12                                 Partidos de vuelta
# 13                                            Jornada
# 14                                         Jornada 10
# 15                                         Jornada 11
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Ejemplo 2
#
# Tabla de retención en la fuente que rigen en el año 2023
#
# https://www.consultorcontable.com/tabla-de-retencion-en-la-fuente-2023/

# %%
todas = pd.read_html("https://www.consultorcontable.com/tabla-de-retencion-en-la-fuente-2023/")

# %%
todas[0]
# Out:
#                                                     0                      1  \
# 0                           Concepto retefuente  2023  Base mínima en UVT  ≥
# 1   Adquisición de bienes  raíces para uso de vivi...      Más de 20.000 UVT
# 2   Adquisición de bienes  raíces para uso de vivi...       Hasta 20.000 UVT
# 3   Adquisición de bienes  raíces para uso diferen...               ≥ 27 UVT
# 4                          Adquisición de  vehículos.               ≥ 27 UVT
# 5   Arrendamiento de bienes  inmuebles (declarante...                     27
# 6                    Arrendamiento de bienes  muebles                      0
# 7                        Comisiones Bolsa de  Valores                      0
# 8                       Comisiones sector  financiero                      0
# 9               Compras con tarjeta  débito o crédito                      0
# 10  Compras de bienes o  productos agrícolas o pec...                     92
# ...

# %% [markdown]
# # [pandas.read_sql](https://pandas.pydata.org/docs/reference/api/pandas.read_sql.html)
